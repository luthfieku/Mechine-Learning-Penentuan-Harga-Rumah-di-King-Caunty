# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('kc_house_data.csv', usecols=['bedrooms', 'bathrooms', 'sqft_living', 'grade', 'price', 'yr_built'])

# %%
#Melihat 5 baris teratas dari data.
#Independent variabel(x) adalah bedrooms, bathrooms, sqft_living, grade, yr_built.
#Dependent variabel(y) adalah price.
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  grade  yr_built
# 0  221900.0         3       1.00         1180      7      1955
# 1  538000.0         3       2.25         2570      7      1951
# 2  180000.0         2       1.00          770      6      1933
# 3  604000.0         4       3.00         1960      7      1965
# 4  510000.0         3       2.00         1680      8      1987

# %%
#Mengetahui jumlah kolom dan baris dari data.
#Data ucup mempunya 6 kolom (features) dengan 21613 baris.
df.shape
# Out:
# (21613, 6)

# %%
#Melihat informasi data ucup mulai dari jumlah data, tipe data, memory yang digunakan dll.
#Dapat dilihat bahwa seluruh data sudah di dalam bentuk numerik.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        21613 non-null  float64
#  1   bedrooms     21613 non-null  int64
#  2   bathrooms    21613 non-null  float64
#  3   sqft_living  21613 non-null  int64
#  4   grade        21613 non-null  int64
#  5   yr_built     21613 non-null  int64
# dtypes: float64(2), int64(4)
# memory usage: 1013.2 KB

# %%
#Merubah tipe data dari bathrooms yang semula float menjadi int.
df['bathrooms'] = df['bathrooms'].astype('int')
#Mengganti nilai 33 menjadi 3.
df['bedrooms'] = df['bedrooms'].replace(33,3)

# %%
#Mencari dan menangani missing values.
#Ternyata datanya sudah tidak ada missing values.
df.isnull().sum()
# Out:
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# grade          0
# yr_built       0
# dtype: int64

# %%
#Univariate analysis bedrooms.
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['bedrooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['bedrooms'])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Univariate analysis bathrooms.

f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['bathrooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['bathrooms'])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Univariate analysis sqft_living.

f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['sqft_living'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['sqft_living'])
plt.show()

# %%
#Univariate analysis grade.

f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['grade'])
f.add_subplot(1,2,2)
plt.boxplot(df['grade'])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Univariate analysis yr_built.

f = plt.figure(figsize=(20,8))
f.add_subplot(1,2,1)
sns.countplot(df['yr_built'])
f.add_subplot(1,2,2)
plt.boxplot(df['yr_built'])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Bivariate analysis antara independent variable dan dependent variable.

plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=['bedrooms', 'bathrooms', 'sqft_living', 'grade', 'yr_built'], y_vars=['price'], size=5, aspect=0.75)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Mengetahui nilai korelasi dari independent variable dan dependent variable.
df.corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
# #T_4a5ca_row0_col0,#T_4a5ca_row1_col1,#T_4a5ca_row2_col2,#T_4a5ca_row3_col3,#T_4a5ca_row4_col4,#T_4a5ca_row5_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_4a5ca_row0_col1{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_4a5ca_row0_col2{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_4a5ca_row0_col3{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_4a5ca_row0_col4{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }#T_4a5ca_row0_col5,#T_4a5ca_row1_col4,#T_4a5ca_row5_col0,#T_4a5ca_row5_col1,#T_4a5ca_row5_col2,#T_4a5ca_row5_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_4a5ca_row1_col0{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_4a5ca_row1_col2{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_4a5ca_row1_col3,#T_4a5ca_row2_col5{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_4a5ca_row1_col5{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_4a5ca_row2_col0{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_4a5ca_row2_col1,#T_4a5ca_row2_col4{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_4a5ca_row2_col3{
#             background-color:  #589ec8;
#             color:  #000000;
#         }#T_4a5ca_row3_col0{
#             background-color:  #1e80b8;
#             color:  #000000;
#         }#T_4a5ca_row3_col1{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_4a5ca_row3_col2{
#             background-color:  #81aed2;
#             color:  #000000;
#         }#T_4a5ca_row3_col4{
#             background-color:  #358fc0;
#             color:  #000000;
#         }#T_4a5ca_row3_col5{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_4a5ca_row4_col0,#T_4a5ca_row4_col3{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_4a5ca_row4_col1{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_4a5ca_row4_col2{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_4a5ca_row4_col5{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_4a5ca_row5_col4{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }</style><table id="T_4a5ca_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>        <th class="col_heading level0 col1" >bedrooms</th>        <th class="col_heading level0 col2" >bathrooms</th>        <th class="col_heading level0 col3" >sqft_living</th>        <th class="col_heading level0 col4" >grade</th>        <th class="col_heading level0 col5" >yr_built</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a5ca_level0_row0" class="row_heading level0 row0" >price</th>
#                         <td id="T_4a5ca_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_4a5ca_row0_col1" class="data row0 col1" >0.32</td>
#                         <td id="T_4a5ca_row0_col2" class="data row0 col2" >0.51</td>
#                         <td id="T_4a5ca_row0_col3" class="data row0 col3" >0.70</td>
#                         <td id="T_4a5ca_row0_col4" class="data row0 col4" >0.67</td>
#                         <td id="T_4a5ca_row0_col5" class="data row0 col5" >0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_4a5ca_level0_row1" class="row_heading level0 row1" >bedrooms</th>
#                         <td id="T_4a5ca_row1_col0" class="data row1 col0" >0.32</td>
#                         <td id="T_4a5ca_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_4a5ca_row1_col2" class="data row1 col2" >0.48</td>
#                         <td id="T_4a5ca_row1_col3" class="data row1 col3" >0.59</td>
#                         <td id="T_4a5ca_row1_col4" class="data row1 col4" >0.37</td>
#                         <td id="T_4a5ca_row1_col5" class="data row1 col5" >0.16</td>
#             </tr>
#             <tr>
#                         <th id="T_4a5ca_level0_row2" class="row_heading level0 row2" >bathrooms</th>
#                         <td id="T_4a5ca_row2_col0" class="data row2 col0" >0.51</td>
#                         <td id="T_4a5ca_row2_col1" class="data row2 col1" >0.48</td>
#                         <td id="T_4a5ca_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_4a5ca_row2_col3" class="data row2 col3" >0.70</td>
#                         <td id="T_4a5ca_row2_col4" class="data row2 col4" >0.61</td>
#                         <td id="T_4a5ca_row2_col5" class="data row2 col5" >0.43</td>
#             </tr>
#             <tr>
#                         <th id="T_4a5ca_level0_row3" class="row_heading level0 row3" >sqft_living</th>
#                         <td id="T_4a5ca_row3_col0" class="data row3 col0" >0.70</td>
#                         <td id="T_4a5ca_row3_col1" class="data row3 col1" >0.59</td>
#                         <td id="T_4a5ca_row3_col2" class="data row3 col2" >0.70</td>
#                         <td id="T_4a5ca_row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_4a5ca_row3_col4" class="data row3 col4" >0.76</td>
#                         <td id="T_4a5ca_row3_col5" class="data row3 col5" >0.32</td>
#             </tr>
#             <tr>
#                         <th id="T_4a5ca_level0_row4" class="row_heading level0 row4" >grade</th>
#                         <td id="T_4a5ca_row4_col0" class="data row4 col0" >0.67</td>
#                         <td id="T_4a5ca_row4_col1" class="data row4 col1" >0.37</td>
#                         <td id="T_4a5ca_row4_col2" class="data row4 col2" >0.61</td>
#                         <td id="T_4a5ca_row4_col3" class="data row4 col3" >0.76</td>
#                         <td id="T_4a5ca_row4_col4" class="data row4 col4" >1.00</td>
#                         <td id="T_4a5ca_row4_col5" class="data row4 col5" >0.45</td>
#             </tr>
#             <tr>
#                         <th id="T_4a5ca_level0_row5" class="row_heading level0 row5" >yr_built</th>
#                         <td id="T_4a5ca_row5_col0" class="data row5 col0" >0.05</td>
#                         <td id="T_4a5ca_row5_col1" class="data row5 col1" >0.16</td>
#                         <td id="T_4a5ca_row5_col2" class="data row5 col2" >0.43</td>
#                         <td id="T_4a5ca_row5_col3" class="data row5 col3" >0.32</td>
#                         <td id="T_4a5ca_row5_col4" class="data row5 col4" >0.45</td>
#                         <td id="T_4a5ca_row5_col5" class="data row5 col5" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
#Pertama, buat variabel x dan y.
x = df.drop(columns='price')
y = df['price']
#Kedua, ucup split data menjadi training and testing dengan porsi 80:20.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)
#Ketiga, ucup bikin object linear regresi.
lin_reg = LinearRegression()
#Keempat, train the model menggunakan training data yang sudah displit.
lin_reg.fit(x_train, y_train)
#Kelima, cari tau nilai slope/koefisien (m) dan intercept (b).
print(lin_reg.coef_)
print(lin_reg.intercept_)
# Out:
# [-53061.75464279  64658.55790617    188.90926343 131290.89536823
#   -3969.55831454]
# 7031568.245717696

# %%
#Keenam, cari tahu accuracy score dari model menggunakan testing data yang sudah displit.
lin_reg.score(x_test, y_test)
# Out:
# 0.61251132869411

# %%
#Prediksi harga rumah idaman Joko.
lin_reg.predict([[3,2,1800,7,1990]])
# Out:
# array([361351.99342265])

# %%
#Prediksi harga rumah idaman lain.
lin_reg.predict([[4,3,1800,7,1990]])
# Out:
# array([372948.79668603])
